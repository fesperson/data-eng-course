# %% [markdown]
# A quick little test

# %%
from pyspark.sql import SparkSession

# Create a Spark session (this starts your local Spark instance)
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("MyFirstSpark") \
    .getOrCreate()

# Get the SparkContext from the session
sc = spark.sparkContext

# Create a simple RDD
rdd = sc.parallelize([1, 2, 3, 4, 5])

# Do something with it
print(rdd.collect())
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/08 02:25:20 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [1, 2, 3, 4, 5]
# 26/06/08 02:25:31 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
rdd2 = rdd.map(lambda x : x**2)
rdd2.sum()
# Out:
# 55

# %%
rdd2.collect()
# Out:
# [1, 4, 9, 16, 25]
